# %%
pip install pyquran

# %%
pip install colorama

# %%
pip install --upgrade googletrans==4.0.0-rc1

# %%
from colorama import Fore, Style

# %%
import pyquran as q

# %%
from googletrans import Translator, constants
from pprint import pprint

# %%
translator = Translator()

def translate_arabic_to_english(text):
    translation = translator.translate(text, src="ar", dest="en")
    return translation.text

# %%
def print_with_color(s, color=Fore.WHITE, brightness=Style.NORMAL, **kwargs):
    print(f"{brightness}{color}{s}{Style.RESET_ALL}", **kwargs)

# %%
print_with_color("THE QURAN", color=Fore.GREEN)
# Out:
# THE QURAN

# %%
def func1():
    n = int(input("Enter surah Number: "))
    ans = q.quran.get_sura(n, with_tashkeel=False, basmalah=True)
    max_line_length = 200  # Maximum allowed length for a line
    for line in ans:
        if len(line) > max_line_length:
            # Split the line into smaller chunks
            chunks = [line[i:i+max_line_length] for i in range(0, len(line), max_line_length)]
            for chunk in chunks:
                print_with_color(chunk, color=Fore.GREEN)
                translated_chunk = translate_arabic_to_english(chunk)
                print_with_color(translated_chunk, color=Fore.BLUE)
        else:
            print_with_color(line, color=Fore.GREEN)
            translated_line = translate_arabic_to_english(line)
            print_with_color(translated_line, color=Fore.BLUE)

# %%
def func2():
    s = int(input("Enter surah Number: "))
    l = int(input("Enter verse Number: "))
    ans = q.quran.get_verse(s, l, with_tashkeel=False)

    translated_ans = translate_arabic_to_english(ans)

    print_with_color(translated_ans, color=Fore.BLUE)

# %%
def func3():
  n=int(input("Enter Surah Number:"))
  ans=q.quran.get_sura_name(n)
  print_with_color(ans, color=Fore.GREEN)
  translated_line = translate_arabic_to_english(ans)
  print_with_color(translated_line, color=Fore.BLUE)

# %%
def main():

    while True:
        print_with_color("Choose From Below", color=Fore.BLUE)
        print_with_color("1-Get Sura", color=Fore.BLUE)
        print_with_color("2-Get Verse", color=Fore.BLUE)
        print_with_color("3-Get Sura Name", color=Fore.BLUE)
        n = int(input("Enter 1-3: "))
        if n < 1 or n > 4:
            print_with_color("Invalid input", color=Fore.RED)
            continue
        if n == 1:
            func1()
        elif n == 2:
            func2()
        elif n == 3:
            func3()
        ch=input("do you Want to continue (y/n)")
        if ch=='n':
          print_with_color("Allah Hafiz",Fore.GREEN)
          break


main()
# Out:
# Choose From Below
# 1-Get Sura
# 2-Get Verse
# 3-Get Sura Name
# Enter 1-3: 3
# Enter Surah Number:52
# الطور
# Phase
# do you Want to continue (y/n)y
# Choose From Below
# 1-Get Sura
# 2-Get Verse
# 3-Get Sura Name
# Enter 1-3: 3
# Enter Surah Number:55
# الرحمن
# merciful
# do you Want to continue (y/n)y
# Choose From Below
# 1-Get Sura
# 2-Get Verse
# 3-Get Sura Name
# Enter 1-3: 1
# Enter surah Number: 55
# بسم الله الرحمن الرحيم
# In the name of God, the most gracious, the most merciful
# الرحمن
# merciful
# علم القرءان
# The flag of the Qur'an
# خلق الإنسن
# Mankind
# علمه البيان
# The statement of the statement
# الشمس والقمر بحسبان
# The sun and the moon are counted
# والنجم والشجر يسجدان
# The star and the trees prostrate
# والسماء رفعها ووضع الميزان
# And the sky raised it and put the scale
# ألا تطغوا فى الميزان
# Don't you overwhelm the scale
# وأقيموا الوزن بالقسط ولا تخسروا الميزان
# And evaluate the weight in installments and do not lose the scale
# والأرض وضعها للأنام
# And the land put it to sleep
# فيها فكهة والنخل ذات الأكمام
# It has a nick and palm tree with sleeves
# والحب ذو العصف والريحان
# And love with storm and basil
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# خلق الإنسن من صلصل كالفخار
# The creation of man from clay as pottery
# وخلق الجان من مارج من نار
# And create the elves from Marg from fire
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# رب المشرقين ورب المغربين
# Lord of the East and Lord of the Maghreb
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# مرج البحرين يلتقيان
# Marj Bahrain meet
# بينهما برزخ لا يبغيان
# Between them is an unjust
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# يخرج منهما اللؤلؤ والمرجان
# Pearl and coral come out of them
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# وله الجوار المنشٔات فى البحر كالأعلم
# And he has the neighborhood in the sea, such as flags
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# كل من عليها فان
# All that is on earth will perish
# ويبقى وجه ربك ذو الجلل والإكرام
# And the face of your Lord remains great and honorable
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# يسٔله من فى السموت والأرض كل يوم هو فى شأن
# It is made by those in the hemoat and the earth every day is regarding
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# سنفرغ لكم أيه الثقلان
# We will empty you, O heavyweights
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# يمعشر الجن والإنس إن استطعتم أن تنفذوا من أقطار السموت والأرض فانفذوا لا تنفذون إلا بسلطن
# The jinn and mankind will be tenth if you can implement from the countries of the Smooty and the Earth, so you will be executed only in Sultan
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# يرسل عليكما شواظ من نار ونحاس فلا تنتصران
# He sends shoes of fire and copper, so do not triumph
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# فإذا انشقت السماء فكانت وردة كالدهان
# If the sky split, it was a rose like paint
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# فيومئذ لا يسٔل عن ذنبه إنس ولا جان
# On that day, he does not ask for his sins or Jean
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# يعرف المجرمون بسيمهم فيؤخذ بالنوصى والأقدام
# Criminals are known as their name, so it is taken as recommended and feet
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# هذه جهنم التى يكذب بها المجرمون
# This is the hell in which criminals lie
# يطوفون بينها وبين حميم ءان
# They circumambulate it with the intimacy
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# ولمن خاف مقام ربه جنتان
# And for those who feared the shrine of his Lord Jintan
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# ذواتا أفنان
# Dhouda Afnan
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# فيهما عينان تجريان
# They have two eyes running
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# فيهما من كل فكهة زوجان
# In them from every bone of a couple
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# متكٔين على فرش بطائنها من إستبرق وجنى الجنتين دان
# Identify on its blanket brushes from Estabrq and the reaping of the two guns Dan
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# فيهن قصرت الطرف لم يطمثهن إنس قبلهم ولا جان
# In them, the party palace, and I did not curse them before them, nor Jean
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# كأنهن الياقوت والمرجان
# As if they are ruby and coral
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# هل جزاء الإحسن إلا الإحسن
# Is the reward for the best except the best?
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# ومن دونهما جنتان
# Without them two gins
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# مدهامتان
# Two sediments
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# فيهما عينان نضاختان
# They have two sample eyes
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# فيهما فكهة ونخل ورمان
# They have a nozzle, palm, and pomegranate
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# فيهن خيرت حسان
# They are good
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# حور مقصورت فى الخيام
# Horcaps in the tents
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# لم يطمثهن إنس قبلهم ولا جان
# I did not recite them before them, nor Jean
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# متكٔين على رفرف خضر وعبقرى حسان
# Identified on the flap of Khadr and the genius of Hassan
# فبأى ءالاء ربكما تكذبان
# In what is your Lord, you are lying
# تبرك اسم ربك ذى الجلل والإكرام
# The name of your Lord is blessed and honored
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-12080311d5bf> in <cell line: 24>()
#      22
#      23
# ---> 24 main()
#
# <ipython-input-26-12080311d5bf> in main()
#      16         elif n == 3:
#      17             func3()
# ---> 18         ch=input("do you Want to continue (y/n)")
#      19         if ch=='n':
#      20           print_with_color("Allah Hafiz",Fore.GREEN)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
